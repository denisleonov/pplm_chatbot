# %%
# !git clone https://github.com/Krolion/PPLM_bot_test.git
# Out:
# Cloning into 'PPLM_bot_test'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 74 (delta 12), reused 70 (delta 9), pack-reused 0
# Unpacking objects: 100% (74/74), done.

# %%
# !pip install -q transformers
# !pip install -q pytorch-ignite
# Out:
#      |████████████████████████████████| 501kB 2.7MB/s
#      |████████████████████████████████| 3.7MB 55.0MB/s
#      |████████████████████████████████| 870kB 37.7MB/s
#      |████████████████████████████████| 1.0MB 52.1MB/s
# ...
#      |████████████████████████████████| 112kB 2.7MB/s

# %% [markdown]
# Replace module_openai.py in transformers

# %%
# !python PPLM_bot_test/interact.py
# Out:
# INFO:PPLM_bot_test/interact.py:Namespace(dataset_cache='./dataset_cache', dataset_path='', device='cpu', max_history=2, max_length=20, min_length=1, model='openai-gpt', model_checkpoint='', no_sample=False, seed=0, temperature=1.0, top_k=10, top_p=0.0)
# INFO:/content/PPLM_bot_test/utils.py:extracting archive file /root/.cache/torch/transformers/2f5114b5eb72f9515802779c42c1b289bebdb1cfc8ce94c653237518eb530b34.75f2a4fe69178ff43138117a977e107a5fc7d402603a0825a296b531f246b3f2 to temp dir /tmp/tmp5h1pr5__
# INFO:PPLM_bot_test/interact.py:Get pretrained model and tokenizer
# INFO:transformers.tokenization_utils:Model name '/tmp/tmp5h1pr5__' not found in model shortcut name list (openai-gpt). Assuming '/tmp/tmp5h1pr5__' is a path, a model identifier, or url to a directory containing tokenizer files.
# INFO:transformers.tokenization_utils:Didn't find file /tmp/tmp5h1pr5__/special_tokens_map.json. We won't load it.
# ...
